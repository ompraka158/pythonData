# %%
import pandas as pd

# %%
movies=pd.read_csv("links.csv")

# %%
movies
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# 5            6   113277     949.0
# 6            7   114319   11860.0
# 7            8   112302   45325.0
# 8            9   114576    9091.0
# 9           10   113189     710.0
# 10          11   112346    9087.0
# 11          12   112896   12110.0
# 12          13   112453   21032.0
# 13          14   113987   10858.0
# 14          15   112760    1408.0
# 15          16   112641     524.0
# 16          17   114388    4584.0
# 17          18   113101       5.0
# 18          19   112281    9273.0
# 19          20   113845   11517.0
# 20          21   113161    8012.0
# 21          22   112722    1710.0
# 22          23   112401    9691.0
# 23          24   114168   12665.0
# 24          25   113627     451.0
# 25          26   114057   16420.0
# ...

# %%
print(type(movies.movieId[0]))
# Out:
# <class 'numpy.int64'>

# %%
print(type(movies))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Correlation

# %% [markdown]
# If we have x and y variables and negative corr applied then x increase and y decreases

# %%
movies.min()
# Out:
# movieId    1.0
# imdbId     1.0
# tmdbId     2.0
# dtype: float64

# %%
movies.max()
# Out:
# movieId     176279.0
# imdbId     7158814.0
# tmdbId      469172.0
# dtype: float64

# %%
movies.mean()
# Out:
# movieId     96578.775626
# imdbId     993708.022032
# tmdbId     108661.382847
# dtype: float64

# %%
movies.std()
# Out:
# movieId    5.721686e+04
# imdbId     1.361924e+06
# tmdbId     1.126660e+05
# dtype: float64

# %%
corr=movies.corr()
corr
# Out:
#           movieId    imdbId    tmdbId
# movieId  1.000000  0.470985  0.556400
# imdbId   0.470985  1.000000  0.753206
# tmdbId   0.556400  0.753206  1.000000

# %%
movies.count()
# Out:
# movieId    45843
# imdbId     45843
# tmdbId     45624
# dtype: int64

# %%
movies.shape
# Out:
# (45843, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# imdbId     False
# tmdbId      True
# dtype: bool

# %%
import numpy as np
np.count_nonzero(movies['tmdbId'].isnull().values)
# Out:
# 219

# %%
null_columns=movies.columns[movies.isnull().any()]
movies[null_columns].isnull().sum()
# Out:
# tmdbId    219
# dtype: int64

# %%
movies['tmdbId'].isnull().value_counts()
# Out:
# False    45624
# True       219
# Name: tmdbId, dtype: int64

# %%
movies["tmdbId"].fillna(method='ffill')
# Out:
# 0           862.0
# 1          8844.0
# 2         15602.0
# 3         31357.0
# 4         11862.0
# 5           949.0
# 6         11860.0
# 7         45325.0
# 8          9091.0
# 9           710.0
# 10         9087.0
# 11        12110.0
# 12        21032.0
# 13        10858.0
# 14         1408.0
# 15          524.0
# 16         4584.0
# 17            5.0
# 18         9273.0
# 19        11517.0
# 20         8012.0
# 21         1710.0
# 22         9691.0
# 23        12665.0
# 24          451.0
# 25        16420.0
# 26         9263.0
# 27        17015.0
# 28          902.0
# 29        37557.0
#            ...
# 45813     45527.0
# 45814    455661.0
# 45815    327237.0
# 45816     84710.0
# 45817     39562.0
# 45818     14008.0
# 45819     44330.0
# 45820     49279.0
# 45821     44333.0
# 45822     49277.0
# 45823     49271.0
# 45824     44324.0
# 45825    122036.0
# 45826     14885.0
# 45827     49280.0
# 45828    106807.0
# 45829    276895.0
# 45830    404604.0
# 45831    420346.0
# ...

# %%
movies['tmdbId'].isnull().value_counts()
# Out:
# False    45624
# True       219
# Name: tmdbId, dtype: int64

# %%
movies=movies.dropna()

# %%
movies
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# 5            6   113277     949.0
# 6            7   114319   11860.0
# 7            8   112302   45325.0
# 8            9   114576    9091.0
# 9           10   113189     710.0
# 10          11   112346    9087.0
# 11          12   112896   12110.0
# 12          13   112453   21032.0
# 13          14   113987   10858.0
# 14          15   112760    1408.0
# 15          16   112641     524.0
# 16          17   114388    4584.0
# 17          18   113101       5.0
# 18          19   112281    9273.0
# 19          20   113845   11517.0
# 20          21   113161    8012.0
# 21          22   112722    1710.0
# 22          23   112401    9691.0
# 23          24   114168   12665.0
# 24          25   113627     451.0
# 25          26   114057   16420.0
# ...

# %%
movies[:50].plot()

# %%
movies[:50].plot.bar()

# %%
movies[:50].plot.hist()

# %%
movies[:50].boxplot()

# %%
movies.drop(movies.index[0])
# Out:
#        movieId   imdbId    tmdbId
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# 5            6   113277     949.0
# 6            7   114319   11860.0
# 7            8   112302   45325.0
# 8            9   114576    9091.0
# 9           10   113189     710.0
# 10          11   112346    9087.0
# 11          12   112896   12110.0
# 12          13   112453   21032.0
# 13          14   113987   10858.0
# 14          15   112760    1408.0
# 15          16   112641     524.0
# 16          17   114388    4584.0
# 17          18   113101       5.0
# 18          19   112281    9273.0
# 19          20   113845   11517.0
# 20          21   113161    8012.0
# 21          22   112722    1710.0
# 22          23   112401    9691.0
# 23          24   114168   12665.0
# 24          25   113627     451.0
# 25          26   114057   16420.0
# 26          27   114011    9263.0
# ...

# %%
movies.groupby('imdbId').count()
# Out:
#          movieId  tmdbId
# imdbId
# 1              1       1
# 3              1       1
# 5              1       1
# 8              1       1
# 10             1       1
# 12             1       1
# 14             1       1
# 23             1       1
# 29             1       1
# 70             1       1
# 75             1       1
# 91             1       1
# 131            1       1
# 132            1       1
# 138            1       1
# 192            1       1
# 211            1       1
# 230            1       1
# 242            1       1
# 246            1       1
# 304            1       1
# 313            1       1
# 359            1       1
# 364            1       1
# 399            1       1
# 417            1       1
# 420            1       1
# 437            1       1
# 439            1       1
# 447            1       1
# ...          ...     ...
# 6736782        1       1
# 6739646        1       1
# 6772874        1       1
# 6792200        1       1
# ...

# %%
ratings=pd.read_csv("ratings.csv")

# %%
ratings.groupby('rating').count()
# Out:
#          userId  movieId  timestamp
# rating
# 0.5      404897   404897     404897
# 1.0      843310   843310     843310
# 1.5      403607   403607     403607
# 2.0     1762440  1762440    1762440
# 2.5     1255358  1255358    1255358
# 3.0     5256722  5256722    5256722
# 3.5     3116213  3116213    3116213
# 4.0     6998802  6998802    6998802
# 4.5     2170441  2170441    2170441
# 5.0     3812499  3812499    3812499
