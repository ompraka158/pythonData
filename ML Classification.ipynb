# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
data=pd.read_csv("weather1.csv")
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am     ...       \
# 0           30.0         SW         NW           6.0     ...
# 1           39.0          E          W           4.0     ...
# 2           85.0          N        NNE           6.0     ...
# 3           54.0        WNW          W          30.0     ...
# 4           50.0        SSE        ESE          20.0     ...
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0           29       1019.7       1015.0         7         7     14.4
# ...

# %%
data.shape
# Out:
# (366, 22)

# %%
data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data.keys()
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data.isnull().any().count()
# Out:
# 22

# %%
before_row = data.shape[0]
before_row
# Out:
# 366

# %%
data = data.dropna()

# %%
after_row = data.shape[0]
after_row
# Out:
# 328

# %%
before_row-after_row
# Out:
# 38

# %% [markdown]
# Convert to a Classification Task

# %%
data.keys()
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data["RainToday"]
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
# 5       No
# 6       No
# 7       No
# 8       No
# 9      Yes
# 10      No
# 11      No
# 12      No
# 13      No
# 14      No
# 15      No
# 16      No
# 17     Yes
# 18      No
# 19      No
# 20      No
# 21      No
# 22     Yes
# 23      No
# 24      No
# 25      No
# 26      No
# 27      No
# 28      No
# 29      No
#       ...
# 333     No
# 334     No
# 335     No
# 336     No
# 337     No
# 338    Yes
# 339    Yes
# 340     No
# 341    Yes
# 342     No
# 343     No
# 344     No
# 345     No
# 346     No
# 347     No
# 349     No
# 350     No
# 352     No
# 353     No
# 354     No
# 355     No
# 356     No
# 357     No
# 358     No
# 359     No
# 361     No
# 362     No
# 363     No
# 364     No
# 365     No
# Name: RainToday, Length: 328, dtype: object

# %%
y=data['RainToday']
y.map({'Yes':1,'No':0})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      1
# 10     0
# 11     0
# 12     0
# 13     0
# 14     0
# 15     0
# 16     0
# 17     1
# 18     0
# 19     0
# 20     0
# 21     0
# 22     1
# 23     0
# 24     0
# 25     0
# 26     0
# 27     0
# 28     0
# 29     0
#       ..
# 333    0
# 334    0
# 335    0
# 336    0
# 337    0
# 338    1
# 339    1
# 340    0
# 341    1
# 342    0
# 343    0
# 344    0
# 345    0
# 346    0
# 347    0
# 349    0
# 350    0
# 352    0
# 353    0
# 354    0
# 355    0
# 356    0
# 357    0
# 358    0
# 359    0
# 361    0
# 362    0
# 363    0
# 364    0
# 365    0
# Name: RainToday, Length: 328, dtype: int64

# %%
clean_data=data[['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
       'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
       'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
       'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
       'Temp3pm', 'RISK_MM']]
clean_data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           30.0         SW         NW           6.0            20
# 1           39.0          E          W           4.0            17
# 2           85.0          N        NNE           6.0             6
# 3           54.0        WNW          W          30.0            24
# 4           50.0        SSE        ESE          20.0            28
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0           68           29       1019.7       1015.0         7         7
# ...

# %%
clean_data['WindGustDir'].unique()     # unique values of directions
# Out:
# array(['NW', 'ENE', 'SSE', 'SE', 'E', 'S', 'N', 'WNW', 'ESE', 'NE', 'NNE',
#        'NNW', 'SW', 'W', 'WSW', 'SSW'], dtype=object)

# %%
directions=clean_data['WindGustDir'].unique()

# %%
directions
# Out:
# array(['NW', 'ENE', 'SSE', 'SE', 'E', 'S', 'N', 'WNW', 'ESE', 'NE', 'NNE',
#        'NNW', 'SW', 'W', 'WSW', 'SSW'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_x=LabelEncoder()
clean_data['WindGustDir']=labelencoder_x.fit_transform(clean_data['WindGustDir'])
clean_data['WindDir9am']=labelencoder_x.fit_transform(clean_data['WindDir9am'])
clean_data['WindDir3pm']=labelencoder_x.fit_transform(clean_data['WindDir3pm'])
clean_data[['WindGustDir','WindDir9am','WindDir3pm']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
clean_data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3            7
# 1       14.0     26.9       3.6          4.4       9.7            1
# 2       13.7     23.4       3.6          5.8       3.3            7
# 3       13.3     15.5      39.8          7.2       9.1            7
# 4        7.6     16.1       2.8          5.6      10.6           10
# 5        6.2     16.9       0.0          5.8       8.2            9
# 6        6.1     18.2       0.2          4.2       8.4            9
# 7        8.3     17.0       0.0          5.6       4.6            0
# 8        8.8     19.5       0.0          4.0       4.1            8
# 9        8.4     22.8      16.2          5.4       7.7            0
# 10       9.1     25.2       0.0          4.2      11.9            3
# 11       8.5     27.3       0.2          7.2      12.5            0
# 12      10.1     27.9       0.0          7.2      13.0           14
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(clean_data,y,test_size=0.4,random_state=30)

# %%
x_train.shape
# Out:
# (196, 20)

# %%
humidity_classifier=DecisionTreeClassifier()

# %%
humidity_classifier.fit(x_train,y_train)
y_test
# Out:
# 228     No
# 263    Yes
# 260     No
# 192     No
# 159     No
# 110     No
# 60      No
# 77     Yes
# 252     No
# 10      No
# 233     No
# 3      Yes
# 67      No
# 78      No
# 35      No
# 21      No
# 169     No
# 101     No
# 84      No
# 120    Yes
# 106     No
# 92     Yes
# 214     No
# 93      No
# 132     No
# 112    Yes
# 96     Yes
# 27      No
# 171     No
# 270    Yes
#       ...
# 346     No
# 251     No
# 167     No
# 54     Yes
# 315     No
# 97      No
# 305    Yes
# 172     No
# 326     No
# 224     No
# 219     No
# 154    Yes
# 269     No
# 335     No
# 292     No
# 191     No
# 242     No
# 285     No
# 131     No
# 103    Yes
# 339    Yes
# 141     No
# 347     No
# 279    Yes
# 160     No
# 109     No
# 317     No
# 23      No
# 308     No
# 48      No
# Name: RainToday, Length: 132, dtype: object

# %%
y_pre=humidity_classifier.predict(x_test)
accuracy_score(y_test,y_pre)
# Out:
# 1.0

# %%
clean_data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3            7
# 1     14.0     26.9       3.6          4.4       9.7            1
# 2     13.7     23.4       3.6          5.8       3.3            7
# 3     13.3     15.5      39.8          7.2       9.1            7
# 4      7.6     16.1       2.8          5.6      10.6           10
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           30.0          12           7           6.0            20
# 1           39.0           0          13           4.0            17
# 2           85.0           3           5           6.0             6
# 3           54.0          14          13          30.0            24
# 4           50.0          10           2          20.0            28
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0           68           29       1019.7       1015.0         7         7
# ...
